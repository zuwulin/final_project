# %%
# import dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# import data

houses = pd.read_csv('resources/GTA_houses_cleaned_dummies.csv')
df = houses
df.head(10)
# Out:
#                                         full_address  bedrooms  bathrooms  \
# 0           6225 Lawrence Ave E, Toronto, ON M1C 5G4         3          4
# 1         3840 Bathurst St #702, Toronto, ON M3H 6C6         2          2
# 2               8 Littleleaf Dr, Toronto, ON M1B 1Z1         3          3
# 3        2301 Danforth Ave #306, Toronto, ON M4C 0A7         2          2
# 4                 16 Catalda Ct, Toronto, ON M2R 3X5         4          5
# 5  2460 Eglinton Ave E PENTHOUSE 12, Toronto, ON ...         2          2
# 6           7 Brimley Rd S #E31, Toronto, ON M1M 3W3         1          1
# 7                   17 Caddy Dr, Toronto, ON M1G 2E9         3          2
# 8              441 Jane St #109, Toronto, ON M6S 3Z9         2          2
# 9       121 Forest Heights Blvd, Toronto, ON M2L 2K7         4          6
#
#      price  Brampton  Markham  Mississauga  Toronto  Vaughan  CONDO  \
# 0   799900         0        0            0        1        0      0
# ...

# %%
# Creating dummy variables
#df = pd.get_dummies(df, columns=['city', 'home type'])
#df.head()

# %%
#identify the input and target variables
X = df.drop(['price','full_address'], axis=1)

y = df[['price']]

# %%
# split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 20, random_state = 2010)

# Train the Model
regr = RandomForestRegressor(n_estimators = 100, random_state = 2010, n_jobs = -1)
regr.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=2010)

# %%
# Make prediction
predictions = regr.predict(X_test)


result = X_test
result['price'] = y_test
result['prediction'] = predictions.tolist()
result['prediction'] = result['prediction'].astype('int')

result.head()
# Out:
#       bedrooms  bathrooms  Brampton  Markham  Mississauga  Toronto  Vaughan  \
# 336          3          2         0        0            0        1        0
# 371          3          2         0        0            0        1        0
# 359          2          2         0        0            0        1        0
# 361          3          2         0        0            0        1        0
# 1759         4          5         0        0            0        0        1
#
#       CONDO  SINGLE_FAMILY  TOWNHOUSE   latitude  longitude    price  \
# 336       0              1          0  43.670834 -79.340720  1549900
# 371       1              0          0  43.731415 -79.328570   999900
# 359       0              1          0  43.609383 -79.495865   599000
# 361       0              1          0  43.705450 -79.526850  1799990
# 1759      0              1          0  43.826160 -79.613180  1588888
#
#       prediction
# 336      1177613
# 371      1089870
# 359       810267
# 361      1075606
# ...

# %%
# Mean squared error (MSE)
mse = mean_squared_error(y_test.values.ravel(), predictions)

# R2 Score
r2 = r2_score(y_test.values.ravel(), predictions)

# Mean Absolute Error
mae = mean_absolute_error(y_test.values.ravel(), predictions)

#Print Results
print("Mean squared error (MSE): ", round(mse, 2))
print("R2 Score: ", round(r2, 2))
print("Mean Absolute Error (MAE): ", round(mae, 2))
# Out:
# Mean squared error (MSE):  225396866584.66
# R2 Score:  0.84
# Mean Absolute Error (MAE):  391852.01
